# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print('ok')
# Out:
# ok

# %%
data1=pd.read_csv(filepath_or_buffer = 'FoodPrice_in_Turkey.csv', sep = ',')
data1.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
data1.to_csv('demo_FoodPrice.csv')
print('ok')
# Out:
# ok

# %%
data1.to_excel('demo_FoodPrice.xlsx')
print('ok')
# Out:
# ok

# %%
data1.to_json('demo_FoodPrice.json',orient='columns')
data1.to_hdf('demo_FoodPrice.h5', 'table')
data1.to_html('demo_FoodPrice.html')
print('ok')
# Out:
# ok
